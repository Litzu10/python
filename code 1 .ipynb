# %% [markdown]
# ## 小程式

# %%
# %pylab inline 
# %matplotlib inline

import numpy as np 
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 1.畫出M

# %%
L=[0, 15, 5, 15, 0]
plot(L, c="green")

# %% [markdown]
# ### 2. 溫度分布圖

# %%
h=(19.1, 19.6, 22.1, 25.7, 29.2, 32, 34.3, 33.8, 
   31.1, 27.5, 24.2, 20.7)
l=(13.9, 14.2, 15.8, 19, 22.3, 24.6, 26.3, 26.1, 
   24.8, 22.3, 19.3, 15.8)
title("Temperature in Taipei",fontsize=15)
xlabel("month")
ylabel("Temperature")
plot(h,c="red")
plot(l)

# %% [markdown]
# ### 3. 買相機

# %%
a=100000
b=150000
c=230000
d=80000
p=[a, a+b, a+b+c, a+b+c+d]
x=["1st","2nd","3rd","4th"]
title("Camera Equipment",fontsize=15)
xlabel("month")
ylabel("cost")
plot(x,p)

# %%
p1=[a,b,c,d]
pie(p1, autopct="%2.2f%%", radius=1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e45464eeb8>,
# ...
#  [Text(0.9313966113234438, 0.5852352966245338, ''),
#   Text(-0.42095177560159874, 1.0162674857624154, ''),
#   Text(-0.6365384137986222, -0.8971169643690471, ''),
#   Text(0.9910657898026469, -0.4772720401226704, '')],
#  [Text(0.5080345152673329, 0.3192192527042911, '17.86%'),
#   Text(-0.22961005941905382, 0.5543277195067721, '26.79%'),
#   Text(-0.34720277116288484, -0.4893365260194802, '41.07%'),
#   Text(0.5405813398923528, -0.2603302037032747, '14.29%')])
